# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       2 from torch import nn
#       3 import matplotlib.pyplot as plt
#
# File d:\Career\python-professional\ds-env\Lib\site-packages\torch\__init__.py:2298
#    2282 ################################################################################
#    2283 # Import most common subpackages
#    2284 ################################################################################
#    (...)   2289
#    2290 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2291 from torch.autograd import (  # usort: skip
#    2292     enable_grad as enable_grad,
#    2293     inference_mode as inference_mode,
#    2294     no_grad as no_grad,
#    2295     set_grad_enabled as set_grad_enabled,
#    2296 )
# -> 2298 from torch import (
#    2299     __config__ as __config__,
#    2300     __future__ as __future__,
#    2301     _awaits as _awaits,
#    2302     accelerator as accelerator,
#    2303     autograd as autograd,
#    2304     backends as backends,
#    2305     cpu as cpu,
#    2306     cuda as cuda,
#    2307     distributed as distributed,
#    2308     distributions as distributions,
#    2309     fft as fft,
#    2310     futures as futures,
#    2311     hub as hub,
#    2312     jit as jit,
#    2313     linalg as linalg,
#    2314     mps as mps,
#    2315     mtia as mtia,
#    2316     multiprocessing as multiprocessing,
#    2317     nested as nested,
#    2318     nn as nn,
#    2319     optim as optim,
#    2320     overrides as overrides,
#    2321     profiler as profiler,
#    2322     sparse as sparse,
#    2323     special as special,
#    2324     testing as testing,
#    2325     types as types,
#    2326     utils as utils,
#    2327     version as version,
#    2328     xpu as xpu,
#    2329 )
#    2330 from torch.signal import windows as windows
#    2333 # Quantized, sparse, AO, etc. should be last to get imported, as nothing
#    2334 # is expected to depend on them.
#
# File d:\Career\python-professional\ds-env\Lib\site-packages\torch\optim\__init__.py:36
#      32 Muon.__module__ = "torch.optim"
#      33 swap_in_optimizer_params_and_state.__module__ = "torch.optim"
# ---> 36 del adadelta  # type: ignore[name-defined] # noqa: F821
#      37 del adagrad  # type: ignore[name-defined] # noqa: F821
#      38 del adam  # type: ignore[name-defined] # noqa: F821
#
# NameError: name 'adadelta' is not defined

# %%
weight = 0.7
bias = 0.3
X = torch.arange(0, 1, 0.02).unsqueeze(dim=1)
y = weight * X + bias

X[:10], y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %%
train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
def plot_predictions(train_data=X_train, 
                     train_labels=y_train, 
                     test_data=X_test, 
                     test_labels=y_test, 
                     predictions=None):
    plt.figure(figsize=(10, 7))
    plt.scatter(train_data, train_labels, c="b", s=4, label="Training data")
    plt.scatter(test_data, test_labels, c="g", s=4, label="Testing data")
    if predictions is not None:
        plt.scatter(test_data, predictions, c="r", s=4, label="Predictions")
    plt.legend(prop={"size": 14})

plot_predictions()

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(1, dtype=torch.float), requires_grad=True)
        self.bias = nn.Parameter(torch.randn(1, dtype=torch.float), requires_grad=True)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.weights * x + self.bias

# %%
torch.manual_seed(42)
model_0 = LinearRegressionModel()
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
with torch.inference_mode(): 
    y_preds = model_0(X_test)

print(f"Number of testing samples: {len(X_test)}") 
print(f"Number of predictions made: {len(y_preds)}")
print(f"Predicted values:\n{y_preds}")
# Out:
# Number of testing samples: 10
# Number of predictions made: 10
# Predicted values:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_predictions(predictions=y_preds)

# %%
# Mean absolute error measures the absolute difference between two
# points (predictions and labels) and then takes the mean across all examples.

loss_fn = nn.L1Loss() # MAE loss is same as L1Loss
optimizer = torch.optim.SGD(params=model_0.parameters(),lr=0.001)

# %% [markdown]
# PyTorch training loop

# %%
torch.manual_seed(42)
epochs = 500
train_loss_values = []
test_loss_values = []
epoch_count = []

for epoch in range(epochs):
    model_0.train()          # Training mode
    y_pred = model_0(X_train)
    loss = loss_fn(y_pred, y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    model_0.eval()           # Evaluation mode
    with torch.inference_mode():
        test_pred = model_0(X_test)
        test_loss = loss_fn(test_pred, y_test.type(torch.float))
        if epoch % 10 == 0:
            epoch_count.append(epoch)
            train_loss_values.append(loss.detach().numpy())
            test_loss_values.append(test_loss.detach().numpy())
            print(f"Epoch: {epoch} | MAE Train Loss: {loss} | MAE Test Loss: {test_loss} ")
# Out:
# Epoch: 0 | MAE Train Loss: 0.008932482451200485 | MAE Test Loss: 0.007100802846252918
# Epoch: 10 | MAE Train Loss: 0.000704666948877275 | MAE Test Loss: 0.0015523552428930998
# Epoch: 20 | MAE Train Loss: 0.0003611445426940918 | MAE Test Loss: 0.0007936537149362266
# Epoch: 30 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 40 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 50 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 60 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 70 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 80 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 90 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 100 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 110 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 120 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 130 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 140 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 150 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 160 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 170 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 180 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 190 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 200 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 210 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 220 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 230 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 240 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 250 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 260 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 270 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 280 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 290 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 300 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 310 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 320 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 330 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 340 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 350 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 360 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 370 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 380 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 390 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 400 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 410 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 420 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 430 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 440 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 450 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 460 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 470 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 480 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05
# Epoch: 490 | MAE Train Loss: 0.0008720018086023629 | MAE Test Loss: 2.879500425478909e-05

# %%
plt.plot(epoch_count, train_loss_values, label="Train loss")
plt.plot(epoch_count, test_loss_values, label="Test loss")
plt.title("Training and test loss curves")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend();

# %%
# Find our model's learned parameters
print("The model learned the following values for weights and bias:")
print(model_0.state_dict())
print("\nAnd the original values for weights and bias are:")
print(f"weights: {weight}, bias: {bias}")
# Out:
# The model learned the following values for weights and bias:
# OrderedDict({'weights': tensor([0.6991]), 'bias': tensor([0.2995])})
#
# And the original values for weights and bias are:
# weights: 0.7, bias: 0.3

# %%
model_0.eval()
with torch.inference_mode():
    y_preds = model_0(X_test)
plot_predictions(predictions=y_preds)

# %%
from pathlib import Path

MODEL_PATH = Path('models')
MODEL_PATH.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "01_pytorch_workflow_model_0.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

torch.save(obj=model_0.state_dict(), f=MODEL_SAVE_PATH)
